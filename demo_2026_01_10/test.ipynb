# %%
import os
import pandas as pd

# %%
data = pd.read_csv('/home/kennys/workspace/MineX/QuantTrading/demo_2026_01_10/screened_stocks.csv')
data_df = pd.DataFrame(data)
data_df
# Out:
#                     date       code   open   high    low  close  preclose  \
# 0    2025-12-29 00:00:00  sh.600602  17.99  19.25  17.91  18.79     17.98
# 1    2025-12-29 00:00:00  sh.600927  15.53  16.55  15.46  16.08     15.49
# 2    2025-12-29 00:00:00  sh.600955  15.68  17.13  15.59  16.82     15.57
# 3    2025-12-29 00:00:00  sh.605111  35.44  37.22  35.44  36.34     34.50
# 4    2025-12-29 00:00:00  sz.300980  29.25  32.91  29.00  32.21     28.82
# ..                   ...        ...    ...    ...    ...    ...       ...
# 114  2026-01-09 00:00:00  sz.300608  11.38  12.12  11.34  12.06     11.39
# 115  2026-01-09 00:00:00  sz.300676  47.99  52.15  47.97  51.69     48.04
# 116  2026-01-09 00:00:00  sz.300729  13.98  14.54  13.92  14.39     13.97
# 117  2026-01-09 00:00:00  sz.300830  10.53  12.86  10.53  12.10     10.72
# 118  2026-01-09 00:00:00  sz.300862  23.69  26.55  23.69  25.44     23.63
#
#        volume        amount     turn
# 0    41958218  7.851413e+08   3.9056
# 1    22576385  3.625300e+08   1.5510
# 2    22945240  3.839545e+08   4.1719
# 3    34698383  1.272980e+09   8.3544
# 4    19109190  6.029120e+08  19.4315
# ..        ...           ...      ...
# 114  18307160  2.162823e+08   6.3660
# 115  19948558  1.011543e+09   4.7948
# 116   9986922  1.421231e+08   3.1362
# 117  80471702  9.662015e+08  23.8728
# 118  18463997  4.680085e+08  12.1898
#
# [119 rows x 10 columns]

# %%
code_list = data_df["code"].tolist()
code_list
# Out:
# ['sh.600602',
#  'sh.600927',
#  'sh.600955',
#  'sh.605111',
#  'sz.300980',
#  'sh.600765',
#  'sh.603037',
#  'sh.603080',
#  'sh.603085',
#  'sh.603205',
#  'sh.603275',
#  'sh.603767',
#  'sz.300579',
#  'sz.300782',
#  'sz.300828',
#  'sz.300879',
#  'sh.600273',
#  'sh.603055',
#  'sh.603726',
#  'sz.300986',
#  'sh.600076',
#  'sh.600232',
#  'sh.600283',
#  'sh.600615',
#  'sh.600648',
#  'sh.600839',
#  'sh.600998',
#  'sh.603309',
#  'sh.603382',
#  'sh.603466',
#  'sh.603713',
#  'sh.605369',
#  'sz.000710',
#  'sz.000810',
#  'sz.300011',
#  'sz.300140',
#  'sz.300143',
#  'sz.300227',
#  'sz.300246',
#  'sz.300451',
#  'sz.300459',
#  'sz.300513',
#  'sz.300678',
#  'sz.300715',
#  'sz.300747',
#  'sz.300793',
#  'sz.300976',
#  'sh.600157',
#  'sh.600589',
#  'sh.600722',
#  'sh.600906',
#  'sh.601216',
#  'sh.601568',
#  'sh.603739',
#  'sh.603810',
#  'sz.000100',
#  'sz.300029',
#  'sz.300163',
#  'sz.300429',
#  'sz.300698',
#  'sz.300746',
#  'sz.300821',
#  'sz.300825',
#  'sz.300827',
#  'sz.300891',
#  'sz.300982',
#  'sh.600121',
#  'sh.600458',
#  'sh.600855',
#  'sh.601666',
#  'sh.603102',
#  'sh.603281',
#  'sh.603339',
#  'sh.603655',
#  'sh.603687',
#  'sh.603916',
#  'sz.000595',
#  'sz.000983',
#  'sz.300066',
#  'sz.300127',
#  'sz.300141',
#  'sz.300420',
#  'sz.300480',
#  'sz.300606',
#  'sz.300797',
#  'sz.300820',
#  'sz.300935',
#  'sh.600435',
#  'sh.600496',
#  'sh.603499',
#  'sh.603588',
#  'sh.603598',
#  'sh.605198',
#  'sz.000620',
#  'sz.300048',
#  'sz.300153',
#  'sz.300353',
#  'sz.300492',
#  'sz.300508',
#  'sz.300792',
#  'sh.600108',
#  'sh.601226',
#  'sh.601811',
#  'sh.603261',
#  'sh.603888',
#  'sh.605116',
#  'sh.605177',
#  'sz.000159',
#  'sz.000803',
#  'sz.300142',
#  'sz.300288',
#  'sz.300553',
#  'sz.300586',
#  'sz.300592',
#  'sz.300608',
#  'sz.300676',
#  'sz.300729',
#  'sz.300830',
#  'sz.300862']

# %%
idx_list = [f.split('.')[1] for f in code_list] 
idx_list
# Out:
# ['600602',
#  '600927',
#  '600955',
#  '605111',
#  '300980',
#  '600765',
#  '603037',
#  '603080',
#  '603085',
#  '603205',
#  '603275',
#  '603767',
#  '300579',
#  '300782',
#  '300828',
#  '300879',
#  '600273',
#  '603055',
#  '603726',
#  '300986',
#  '600076',
#  '600232',
#  '600283',
#  '600615',
#  '600648',
#  '600839',
#  '600998',
#  '603309',
#  '603382',
#  '603466',
#  '603713',
#  '605369',
#  '000710',
#  '000810',
#  '300011',
#  '300140',
#  '300143',
#  '300227',
#  '300246',
#  '300451',
#  '300459',
#  '300513',
#  '300678',
#  '300715',
#  '300747',
#  '300793',
#  '300976',
#  '600157',
#  '600589',
#  '600722',
#  '600906',
#  '601216',
#  '601568',
#  '603739',
#  '603810',
#  '000100',
#  '300029',
#  '300163',
#  '300429',
#  '300698',
#  '300746',
#  '300821',
#  '300825',
#  '300827',
#  '300891',
#  '300982',
#  '600121',
#  '600458',
#  '600855',
#  '601666',
#  '603102',
#  '603281',
#  '603339',
#  '603655',
#  '603687',
#  '603916',
#  '000595',
#  '000983',
#  '300066',
#  '300127',
#  '300141',
#  '300420',
#  '300480',
#  '300606',
#  '300797',
#  '300820',
#  '300935',
#  '600435',
#  '600496',
#  '603499',
#  '603588',
#  '603598',
#  '605198',
#  '000620',
#  '300048',
#  '300153',
#  '300353',
#  '300492',
#  '300508',
#  '300792',
#  '600108',
#  '601226',
#  '601811',
#  '603261',
#  '603888',
#  '605116',
#  '605177',
#  '000159',
#  '000803',
#  '300142',
#  '300288',
#  '300553',
#  '300586',
#  '300592',
#  '300608',
#  '300676',
#  '300729',
#  '300830',
#  '300862']
